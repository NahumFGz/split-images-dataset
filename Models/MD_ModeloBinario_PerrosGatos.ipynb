# %% [markdown]
# # Información de hardware
# https://colab.research.google.com/notebooks/pro.ipynb?authuser=2#scrollTo=23TOba33L4qf

# %%
import warnings
warnings.filterwarnings("ignore")

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Tue May 28 16:54:37 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
  print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
  print('re-execute this cell.')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# To enable a high-RAM runtime, select the Runtime > "Change runtime type"
# menu, and then select High-RAM in the Runtime shape dropdown. Then,
# re-execute this cell.

# %% [markdown]
# ### Conectado a Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pip-chill
# !pip-chill

# %% [markdown]
# ### Librerias

# %%
import os
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import math
import keras.callbacks
from keras.layers import *
from keras.applications import *
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import model_from_json
from keras import backend as k
from keras import optimizers
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# ### Variables globales - (Guardar resultados)

# %%
gb_dataset_type  = 'Otros'
gb_dataset_name  = 'PerrosGatos'

gb_datasets_dir  = os.path.join('/content/drive/MyDrive/Colab Notebooks/DataSets', gb_dataset_type, gb_dataset_name)
gb_result_dir    = os.path.join('/content/drive/MyDrive/Colab Notebooks/ResultadosEntrenamiento', gb_dataset_type, gb_dataset_name)

gb_nb_clases  = 2

# %% [markdown]
# ### Graficar precisión y perdidas

# %%
def plot_loss_accurancy(history, write_path):
  #Valores a graficar
  acc      = history.history['accuracy']
  val_acc  = history.history['val_accuracy']
  loss     = history.history['loss']
  val_loss = history.history['val_loss']

  #Definir gráficos
  plt.figure(1)
  plt.plot(acc)
  plt.plot(val_acc)
  plt.title('Model Accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epochs')
  plt.legend(['Train', 'Validation'], loc='upper left')
  fig_accu =  plt.figure(1)

  plt.figure(2)
  plt.plot(loss)
  plt.plot(val_loss)
  plt.title('Model Losses')
  plt.ylabel('Loss')
  plt.xlabel('Epochs')
  plt.legend(['Train', 'Validation'], loc='upper left')
  fig_loss =  plt.figure(2)
  plt.show()

  #Guardar gráficos
  fig_accu.savefig(os.path.join(gb_result_dir, write_path + 'accu.png'))
  fig_loss.savefig(os.path.join(gb_result_dir, write_path + 'loss.png'))

  #Guardar datos de entrenamiento
  df_a = pd.DataFrame(acc, columns = ['accuracy'])
  df_b = pd.DataFrame(val_acc, columns = ['val_accuracy'])
  df_c = pd.DataFrame(loss, columns = ['loss'])
  df_d = pd.DataFrame(val_loss, columns = ['val_loss'])

  frames = [df_a,df_b,df_c,df_d]
  df = pd.concat(frames, axis=1)

  df.to_csv(os.path.join(gb_result_dir, write_path + 'History.csv'), index=False)

  print('Datos entrenamiento y Gráficos guardados!!!\n')

# %% [markdown]
# ### Guardar resultados modelo y pesos

# %%
def save_model_weigths(model,write_path):
  #Save model
  # model_json = model.to_json()
  # with open(os.path.join(gb_result_dir, write_path + 'model.json'), "w") as json_file:
  #     json_file.write(model_json)

  #Save weigths
  # model.save(os.path.join(gb_result_dir, write_path + 'weigths.h5'))

  print('\nModelo y pesos guardados!!!\n')

# %% [markdown]
# ### Guardar resultados de valid-test

# %%
def save_results(stats, write_path):
  df_a = pd.DataFrame(stats[0][0], columns=['Filenames'])
  df_b = pd.DataFrame(stats[0][1], columns=['classes'])
  df_c = pd.DataFrame(stats[0][2], columns=['prob_clase_1','prob_clase_2'])
  df_d = pd.DataFrame(stats[0][3], columns=['pred'])

  frames = [df_a,df_b,df_c,df_d]

  df = pd.concat(frames, axis=1)
  # df.to_csv(write_path, index=False)

  flg_message = False if 'ValidPredicts.csv' in write_path else True

  if flg_message:
    print('Test.csv guardado!!!')

# %% [markdown]
# ### Dimensiones

# %%
def getImageDims(model):
    if model == 'VGG16' or model == 'VGG19' or model == 'InceptionResNetV2':
        width, height = 224, 224

    elif model == 'ResNet50' or model == 'ResNet101' or model == 'ResNet50V2':
        width, height = 224, 224

    elif model == 'DenseNet121' or model == 'DenseNet169':
        width, height = 224, 224

    elif model == 'InceptionV3' or model == 'Xception':
        width, height = 299, 299

    elif model == 'NASNetLarge':
        width, height = 331, 331

    elif model == 'MobileNet' or model == 'MobileNetV2' or model == 'NASNetMobile':
        width, height = 224, 224

    return width, height

# %% [markdown]
# ### Fine tuning class

# %%
# fix seed for reproducible results (only works on CPU, not GPU)
seed = 101
np.random.seed(seed=seed)
tf.random.set_seed(seed=seed)

# %%
class CNN_classifier_generator(object):
    def __init__(self, classifier_name, numEpochs, batch_size,learning_rate, top_model,based_model_last_block_layer_number, train_dir,
                 valid_dir, test_dir,nomenclature):

        # hyper parameters for model
        self.modelNameResults = classifier_name # Classifier name
        self.based_model_last_block_layer_number = based_model_last_block_layer_number   # value is based on based model selected
        self.img_width, self.img_height = getImageDims(self.modelNameResults)  # change based on the architecture
        self.batch_size = batch_size  # powers of 2 values
        self.numEpochs = numEpochs
        self.nb_classes = gb_nb_clases  #3    # number of classes
        self.learn_rate = learning_rate #1e-4 # sgd learning rate
        self.momentum = .9  # sgd momentum to avoid local minimum
        self.transformation_ratio = .2  # how aggressive will be the data augmentation/transformation

        print('------------ lr: '+ str(self.learn_rate) + ' - batch_size: ' + str(self.batch_size) + '------------')

        # Paths
        self.train_dir = train_dir
        self.valid_dir = valid_dir
        self.test_dir = test_dir
        self.top_model = top_model
        self.nomenclature = nomenclature

        # Creating model

        # Pre-Trained CNN Model using imagenet dataset for pre-trained weights
        base_model = globals()[self.modelNameResults](input_shape=(self.img_width, self.img_height, 3), weights='imagenet', include_top=False)

        # Top Model Block
        if self.top_model == 1:
            x = base_model.output
            x = GlobalAveragePooling2D()(x)
            predictions = Dense(self.nb_classes, activation='softmax')(x)

        elif self.top_model == 2:
            # Top model from https://gist.github.com/fchollet/7eb39b44eb9e16e59632d25fb3119975
            x = base_model.output
            x = Flatten(input_shape = base_model.output_shape[1:])(x)
            x = Dense(256, activation='relu')(x)
            x = Dropout(0.4)(x)
            x = Dense(128, activation='relu')(x)
            x = Dropout(0.4)(x)
            predictions = Dense(self.nb_classes, activation='softmax')(x)

         # add top layer block to base model
        self.model = Model(base_model.input, predictions)

        #Summary
        #self.model.summary()


    def train(self, nb_train_samples, nb_validation_samples):
      # Data generator
      train_datagen = ImageDataGenerator(rescale=1. / 255,
                                        rotation_range=self.transformation_ratio,
                                        zoom_range=self.transformation_ratio,
                                        cval=self.transformation_ratio,
                                        horizontal_flip=True,
                                        vertical_flip=True
                                        )

      validation_datagen = ImageDataGenerator(rescale=1. / 255
                                              )


      train_generator = train_datagen.flow_from_directory(self.train_dir,
                                                          target_size=(self.img_width, self.img_height),
                                                          batch_size=self.batch_size,
                                                          class_mode='categorical'
                                                          )
      print(train_generator.samples)


      validation_generator = validation_datagen.flow_from_directory(self.valid_dir,
                                                                    target_size=(self.img_width, self.img_height),
                                                                    batch_size=self.batch_size,
                                                                    class_mode='categorical')
      print(validation_generator.samples)

      # Here we defined the layers we want to use from the base model
      for layer in self.model.layers[:self.based_model_last_block_layer_number]:
        layer.trainable = False
      for layer in self.model.layers[self.based_model_last_block_layer_number:]:
        layer.trainable = True



      # compile the model with a SGD/momentum optimizer and a very slow learning rate.
      self.model.compile(optimizer= optimizers.SGD(learning_rate=self.learn_rate, momentum=self.momentum),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])

      # save weights of best training epoch: monitor either val_loss or val_acc
      # final_weights_path = os.path.join(os.path.abspath(self.model_path), self.model_weights)

      # callbacks_list = [
      #    ModelCheckpoint(final_weights_path, monitor='val_acc', verbose=1, save_best_only=True),
      # ]

      print("\nStarting to Fine Tune Model\n")

      # fine-tune the model
      history = self.model.fit(train_generator,
                                    steps_per_epoch= nb_train_samples // self.batch_size,
                                    epochs=self.numEpochs,
                                    validation_data=validation_generator,
                                    validation_steps= nb_validation_samples // self.batch_size,
                                    verbose = 1,
                                    #callbacks=callbacks_list
                                    )

      #Save model
      save_model_weigths(self.model,self.nomenclature)

      # Plot histoy
      plot_loss_accurancy(history, self.nomenclature)


    def classify(self, test_dir):

      # Read Data
      test_datagen = ImageDataGenerator(rescale=1. / 255
                                        )

      test_generator = test_datagen.flow_from_directory(test_dir,
                                                        target_size=(self.img_width, self.img_height),
                                                        batch_size= self.batch_size,
                                                        shuffle=False)

      # Calculate class posteriors probabilities
      y_probabilities = self.model.predict(test_generator,
                                           steps=np.math.ceil(test_generator.samples / float(test_generator.batch_size))
                                          )

      # Confusion Matrix
      y_pred = np.argmax(y_probabilities, axis=1)
      #print('Confusion Matrix')
      #print(confusion_matrix(test_generator.classes, y_pred))

      print('Classification Report')
      target_names = ['not_sick', 'sick']
      print(classification_report(test_generator.classes, y_pred, target_names=target_names, digits=4))

      return test_generator.filenames,test_generator.classes,y_probabilities,y_pred

# %% [markdown]
# ### Entrenar modelo

# %%
def train_evaluate_save_model (f_arch,f_num_epochs, f_batch, f_lrate, f_top_model, f_nfold, f_nomenclature):
    data_dir = gb_datasets_dir+'/'+ f_nfold +'/'
    train_dir   =  data_dir + 'train/'  # Inside, each class should have it's own folder
    valid_dir   = data_dir + 'valid/'
    test_dir    = data_dir + 'test/'  # each class should have it's own folder

    print('\n',data_dir)


    arch            = f_arch
    numEpochs       = f_num_epochs
    batch_size      = f_batch
    l_rate          = f_lrate
    top_model       = f_top_model
    layer2finetune  = 0 #To evaluate finetune


    classifier = CNN_classifier_generator(classifier_name=arch, numEpochs=numEpochs, batch_size=batch_size, learning_rate=l_rate ,top_model = top_model,
                                          based_model_last_block_layer_number=layer2finetune, train_dir = train_dir,
                                          valid_dir = valid_dir, test_dir = test_dir,nomenclature = f_nomenclature) # 1 means the top model one

    # Counting the number of training and -validation images
    nb_train_samples      = 0
    nb_validation_samples = 0

    for _, _, filesTrain in os.walk(train_dir):
      nb_train_samples = len(filesTrain)

    for _, _, filesDir in os.walk(valid_dir):
      nb_validation_samples = len(filesDir)

    # train model
    classifier.train( nb_train_samples = nb_train_samples, nb_validation_samples = nb_validation_samples)

    # evaluate model
    print('----------Test----------')
    t_filenames, t_classes, t_probabilities, t_pred = classifier.classify(test_dir=test_dir)  # Classify images

    return [t_filenames, t_classes, t_probabilities, t_pred]

# %% [markdown]
# ### Validación cruzada 10k-Fods

# %%
#folds = ['Fold0', 'Fold1', 'Fold2', 'Fold3', 'Fold4', 'Fold5', 'Fold6', 'Fold7', 'Fold8', 'Fold9']

folds   = ['Fold0']
lrates  = [1e-4]
epochs  = [100]
batches = [8]

t_stats    = list()

def cross_validation(f_arch, f_top_model):
  count = 0
  for fold in folds:
    for lrate in lrates:
      for epoch in epochs:
        for batch in batches:

          t_stats.clear()

          print('\n\n---------------------Parametros | Hiperparametros--------------------')
          print('Recorrido: ' + str(count) + '\t' + fold + '\tlr: ' + str(lrate) + '\tbatch: ' + str(batch) + '\tepoch: ' + str(epoch))
          print('---------------------------------------------------------------------')

          #ada: All Data Augmentation
          nomenclature = str(gb_nb_clases) + '_' + f_arch + '_sm' + str(f_top_model) + '_bch' + str(batch) +'_lr' + str(lrate) + '_ep' + str(epoch) + '_ada_' + fold + '_'
          print(nomenclature)

          result_test = train_evaluate_save_model(f_arch,epoch, batch, lrate, f_top_model, fold, nomenclature)

          t_stats.append(result_test)

          save_results(t_stats, os.path.join(gb_result_dir, nomenclature + 'TestPredicts.csv'))

          count+=1
          print('--------------------Fin fold ' + str(fold) + '--------------------')

# %% [markdown]
# ### Entrenamiento de modelos

# %% [markdown]
# * DenseNet121
# * DenseNet169
# * InceptionV3
# * MobileNet
# * MobileNetV2
# * NASNetMobile
# * ResNet101
# * ResNet50
# * ResNet50V2
# * VGG16
# * VGG19
# * Xception

# %%
cross_validation('DenseNet121', 1)
# Out:
# ---------------------Parametros | Hiperparametros--------------------
# Recorrido: 0	Fold0	lr: 0.0001	batch: 8	epoch: 100
# ---------------------------------------------------------------------
# 2_DenseNet121_sm1_bch8_lr0.0001_ep100_ada_Fold0_
#
#  /content/drive/MyDrive/Colab Notebooks/DataSets/Otros/PerrosGatos/Fold0/
# ------------ lr: 0.0001 - batch_size: 8------------
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 1s 0us/step
# Found 1620 images belonging to 2 classes.
# 1620
# Found 200 images belonging to 2 classes.
# 200
#
# Starting to Fine Tune Model
#
# Epoch 1/100
# 100/100 [==============================] - 303s 2s/step - loss: 0.5628 - accuracy: 0.7075 - val_loss: 0.2275 - val_accuracy: 0.9167
# Epoch 2/100
# 100/100 [==============================] - 136s 1s/step - loss: 0.3268 - accuracy: 0.8668 - val_loss: 0.1288 - val_accuracy: 0.9583
# Epoch 3/100
# 100/100 [==============================] - 65s 652ms/step - loss: 0.2574 - accuracy: 0.8975 - val_loss: 0.0859 - val_accuracy: 0.9896
# Epoch 4/100
# 100/100 [==============================] - 41s 411ms/step - loss: 0.2790 - accuracy: 0.8857 - val_loss: 0.1011 - val_accuracy: 0.9792
# Epoch 5/100
# 100/100 [==============================] - 33s 330ms/step - loss: 0.2223 - accuracy: 0.9000 - val_loss: 0.0680 - val_accuracy: 0.9896
# Epoch 6/100
# 100/100 [==============================] - 26s 262ms/step - loss: 0.1758 - accuracy: 0.9384 - val_loss: 0.0530 - val_accuracy: 0.9896
# Epoch 7/100
# 100/100 [==============================] - 24s 240ms/step - loss: 0.1991 - accuracy: 0.9200 - val_loss: 0.0735 - val_accuracy: 0.9688
# Epoch 8/100
# 100/100 [==============================] - 20s 195ms/step - loss: 0.1693 - accuracy: 0.9388 - val_loss: 0.0826 - val_accuracy: 0.9688
# Epoch 9/100
# 100/100 [==============================] - 20s 198ms/step - loss: 0.1575 - accuracy: 0.9350 - val_loss: 0.0950 - val_accuracy: 0.9583
# Epoch 10/100
# 100/100 [==============================] - 20s 195ms/step - loss: 0.1266 - accuracy: 0.9525 - val_loss: 0.0471 - val_accuracy: 1.0000
# Epoch 11/100
# 100/100 [==============================] - 19s 189ms/step - loss: 0.1617 - accuracy: 0.9400 - val_loss: 0.0705 - val_accuracy: 0.9792
# Epoch 12/100
# 100/100 [==============================] - 20s 195ms/step - loss: 0.1487 - accuracy: 0.9447 - val_loss: 0.0524 - val_accuracy: 0.9896
# Epoch 13/100
# 100/100 [==============================] - 19s 190ms/step - loss: 0.1652 - accuracy: 0.9334 - val_loss: 0.0868 - val_accuracy: 0.9688
# Epoch 14/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.1515 - accuracy: 0.9422 - val_loss: 0.0556 - val_accuracy: 0.9896
# Epoch 15/100
# 100/100 [==============================] - 20s 201ms/step - loss: 0.1532 - accuracy: 0.9410 - val_loss: 0.0519 - val_accuracy: 0.9792
# Epoch 16/100
# 100/100 [==============================] - 19s 185ms/step - loss: 0.1208 - accuracy: 0.9598 - val_loss: 0.0296 - val_accuracy: 1.0000
# Epoch 17/100
# 100/100 [==============================] - 19s 193ms/step - loss: 0.1719 - accuracy: 0.9337 - val_loss: 0.0337 - val_accuracy: 1.0000
# Epoch 18/100
# 100/100 [==============================] - 20s 199ms/step - loss: 0.1463 - accuracy: 0.9450 - val_loss: 0.0388 - val_accuracy: 1.0000
# Epoch 19/100
# 100/100 [==============================] - 18s 180ms/step - loss: 0.1304 - accuracy: 0.9535 - val_loss: 0.0744 - val_accuracy: 0.9792
# Epoch 20/100
# 100/100 [==============================] - 19s 188ms/step - loss: 0.0906 - accuracy: 0.9688 - val_loss: 0.0267 - val_accuracy: 1.0000
# Epoch 21/100
# 100/100 [==============================] - 20s 198ms/step - loss: 0.1407 - accuracy: 0.9438 - val_loss: 0.0736 - val_accuracy: 0.9792
# Epoch 22/100
# 100/100 [==============================] - 19s 189ms/step - loss: 0.1071 - accuracy: 0.9563 - val_loss: 0.0364 - val_accuracy: 0.9896
# Epoch 23/100
# 100/100 [==============================] - 19s 190ms/step - loss: 0.1029 - accuracy: 0.9650 - val_loss: 0.1042 - val_accuracy: 0.9688
# Epoch 24/100
# 100/100 [==============================] - 19s 186ms/step - loss: 0.1301 - accuracy: 0.9510 - val_loss: 0.0279 - val_accuracy: 1.0000
# Epoch 25/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.1356 - accuracy: 0.9500 - val_loss: 0.0359 - val_accuracy: 0.9896
# Epoch 26/100
# 100/100 [==============================] - 20s 195ms/step - loss: 0.0710 - accuracy: 0.9700 - val_loss: 0.0662 - val_accuracy: 0.9688
# Epoch 27/100
# 100/100 [==============================] - 18s 180ms/step - loss: 0.0890 - accuracy: 0.9698 - val_loss: 0.0235 - val_accuracy: 0.9896
# Epoch 28/100
# 100/100 [==============================] - 20s 197ms/step - loss: 0.1087 - accuracy: 0.9563 - val_loss: 0.0574 - val_accuracy: 0.9896
# Epoch 29/100
# 100/100 [==============================] - 20s 193ms/step - loss: 0.1094 - accuracy: 0.9563 - val_loss: 0.0523 - val_accuracy: 0.9896
# Epoch 30/100
# 100/100 [==============================] - 19s 190ms/step - loss: 0.1130 - accuracy: 0.9648 - val_loss: 0.0253 - val_accuracy: 1.0000
# Epoch 31/100
# 100/100 [==============================] - 21s 205ms/step - loss: 0.1053 - accuracy: 0.9700 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 32/100
# 100/100 [==============================] - 19s 193ms/step - loss: 0.1104 - accuracy: 0.9585 - val_loss: 0.0299 - val_accuracy: 0.9896
# Epoch 33/100
# 100/100 [==============================] - 19s 194ms/step - loss: 0.0948 - accuracy: 0.9623 - val_loss: 0.0630 - val_accuracy: 0.9792
# Epoch 34/100
# 100/100 [==============================] - 21s 207ms/step - loss: 0.0729 - accuracy: 0.9725 - val_loss: 0.0404 - val_accuracy: 0.9896
# Epoch 35/100
# 100/100 [==============================] - 23s 230ms/step - loss: 0.0613 - accuracy: 0.9812 - val_loss: 0.0256 - val_accuracy: 0.9896
# Epoch 36/100
# 100/100 [==============================] - 21s 207ms/step - loss: 0.0820 - accuracy: 0.9736 - val_loss: 0.0522 - val_accuracy: 0.9896
# Epoch 37/100
# 100/100 [==============================] - 20s 201ms/step - loss: 0.0943 - accuracy: 0.9638 - val_loss: 0.0394 - val_accuracy: 0.9896
# Epoch 38/100
# 100/100 [==============================] - 21s 207ms/step - loss: 0.0801 - accuracy: 0.9712 - val_loss: 0.0229 - val_accuracy: 0.9896
# Epoch 39/100
# 100/100 [==============================] - 19s 188ms/step - loss: 0.0741 - accuracy: 0.9686 - val_loss: 0.0659 - val_accuracy: 0.9792
# Epoch 40/100
# 100/100 [==============================] - 21s 208ms/step - loss: 0.0600 - accuracy: 0.9824 - val_loss: 0.0446 - val_accuracy: 0.9896
# Epoch 41/100
# 100/100 [==============================] - 20s 203ms/step - loss: 0.0504 - accuracy: 0.9862 - val_loss: 0.0226 - val_accuracy: 0.9896
# Epoch 42/100
# 100/100 [==============================] - 20s 200ms/step - loss: 0.0628 - accuracy: 0.9775 - val_loss: 0.0289 - val_accuracy: 0.9896
# Epoch 43/100
# 100/100 [==============================] - 20s 197ms/step - loss: 0.0665 - accuracy: 0.9775 - val_loss: 0.0465 - val_accuracy: 0.9792
# Epoch 44/100
# 100/100 [==============================] - 21s 213ms/step - loss: 0.1151 - accuracy: 0.9700 - val_loss: 0.0402 - val_accuracy: 0.9792
# Epoch 45/100
# 100/100 [==============================] - 19s 193ms/step - loss: 0.0879 - accuracy: 0.9775 - val_loss: 0.0334 - val_accuracy: 0.9896
# Epoch 46/100
# 100/100 [==============================] - 20s 203ms/step - loss: 0.0621 - accuracy: 0.9800 - val_loss: 0.0176 - val_accuracy: 1.0000
# Epoch 47/100
# 100/100 [==============================] - 22s 214ms/step - loss: 0.0866 - accuracy: 0.9688 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 48/100
# 100/100 [==============================] - 21s 204ms/step - loss: 0.0904 - accuracy: 0.9673 - val_loss: 0.0152 - val_accuracy: 1.0000
# Epoch 49/100
# 100/100 [==============================] - 21s 207ms/step - loss: 0.0538 - accuracy: 0.9825 - val_loss: 0.0705 - val_accuracy: 0.9896
# Epoch 50/100
# 100/100 [==============================] - 22s 214ms/step - loss: 0.0513 - accuracy: 0.9825 - val_loss: 0.0259 - val_accuracy: 0.9896
# Epoch 51/100
# 100/100 [==============================] - 22s 215ms/step - loss: 0.0765 - accuracy: 0.9737 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 52/100
# 100/100 [==============================] - 21s 207ms/step - loss: 0.0426 - accuracy: 0.9937 - val_loss: 0.0290 - val_accuracy: 0.9896
# Epoch 53/100
# 100/100 [==============================] - 19s 187ms/step - loss: 0.0679 - accuracy: 0.9799 - val_loss: 0.0335 - val_accuracy: 0.9792
# Epoch 54/100
# 100/100 [==============================] - 19s 190ms/step - loss: 0.0735 - accuracy: 0.9750 - val_loss: 0.0570 - val_accuracy: 0.9896
# Epoch 55/100
# 100/100 [==============================] - 22s 214ms/step - loss: 0.0681 - accuracy: 0.9775 - val_loss: 0.0253 - val_accuracy: 0.9896
# Epoch 56/100
# 100/100 [==============================] - 21s 210ms/step - loss: 0.0589 - accuracy: 0.9849 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 57/100
# 100/100 [==============================] - 20s 196ms/step - loss: 0.0541 - accuracy: 0.9812 - val_loss: 0.0662 - val_accuracy: 0.9792
# Epoch 58/100
# 100/100 [==============================] - 20s 197ms/step - loss: 0.0351 - accuracy: 0.9937 - val_loss: 0.0613 - val_accuracy: 0.9896
# Epoch 59/100
# 100/100 [==============================] - 22s 222ms/step - loss: 0.0834 - accuracy: 0.9749 - val_loss: 0.0597 - val_accuracy: 0.9792
# Epoch 60/100
# 100/100 [==============================] - 20s 203ms/step - loss: 0.0555 - accuracy: 0.9800 - val_loss: 0.0540 - val_accuracy: 0.9896
# Epoch 61/100
# 100/100 [==============================] - 22s 215ms/step - loss: 0.0521 - accuracy: 0.9862 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 62/100
# 100/100 [==============================] - 20s 194ms/step - loss: 0.0557 - accuracy: 0.9812 - val_loss: 0.0233 - val_accuracy: 0.9896
# Epoch 63/100
# 100/100 [==============================] - 19s 191ms/step - loss: 0.0365 - accuracy: 0.9937 - val_loss: 0.0233 - val_accuracy: 1.0000
# Epoch 64/100
# 100/100 [==============================] - 19s 189ms/step - loss: 0.0390 - accuracy: 0.9862 - val_loss: 0.0390 - val_accuracy: 0.9896
# Epoch 65/100
# 100/100 [==============================] - 20s 194ms/step - loss: 0.0429 - accuracy: 0.9825 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 66/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.0518 - accuracy: 0.9786 - val_loss: 0.0365 - val_accuracy: 0.9896
# Epoch 67/100
# 100/100 [==============================] - 19s 186ms/step - loss: 0.0549 - accuracy: 0.9812 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 68/100
# 100/100 [==============================] - 20s 198ms/step - loss: 0.0837 - accuracy: 0.9700 - val_loss: 0.0423 - val_accuracy: 0.9896
# Epoch 69/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.0564 - accuracy: 0.9900 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 70/100
# 100/100 [==============================] - 20s 197ms/step - loss: 0.0202 - accuracy: 0.9962 - val_loss: 0.0130 - val_accuracy: 1.0000
# Epoch 71/100
# 100/100 [==============================] - 19s 190ms/step - loss: 0.0591 - accuracy: 0.9812 - val_loss: 0.0374 - val_accuracy: 0.9792
# Epoch 72/100
# 100/100 [==============================] - 19s 188ms/step - loss: 0.0514 - accuracy: 0.9799 - val_loss: 0.0735 - val_accuracy: 0.9688
# Epoch 73/100
# 100/100 [==============================] - 20s 200ms/step - loss: 0.0352 - accuracy: 0.9900 - val_loss: 0.0215 - val_accuracy: 1.0000
# Epoch 74/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.0574 - accuracy: 0.9849 - val_loss: 0.0628 - val_accuracy: 0.9792
# Epoch 75/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.0341 - accuracy: 0.9887 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 76/100
# 100/100 [==============================] - 20s 200ms/step - loss: 0.0467 - accuracy: 0.9887 - val_loss: 0.0496 - val_accuracy: 0.9792
# Epoch 77/100
# 100/100 [==============================] - 18s 179ms/step - loss: 0.0418 - accuracy: 0.9874 - val_loss: 0.0224 - val_accuracy: 0.9896
# Epoch 78/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.0751 - accuracy: 0.9698 - val_loss: 0.0214 - val_accuracy: 0.9896
# Epoch 79/100
# 100/100 [==============================] - 19s 193ms/step - loss: 0.0715 - accuracy: 0.9800 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 80/100
# 100/100 [==============================] - 18s 180ms/step - loss: 0.0643 - accuracy: 0.9786 - val_loss: 0.0220 - val_accuracy: 1.0000
# Epoch 81/100
# 100/100 [==============================] - 20s 194ms/step - loss: 0.0335 - accuracy: 0.9887 - val_loss: 0.0380 - val_accuracy: 0.9792
# Epoch 82/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.0348 - accuracy: 0.9925 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 83/100
# 100/100 [==============================] - 19s 188ms/step - loss: 0.0270 - accuracy: 0.9899 - val_loss: 0.0442 - val_accuracy: 0.9792
# Epoch 84/100
# 100/100 [==============================] - 20s 203ms/step - loss: 0.0228 - accuracy: 0.9925 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 85/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.0706 - accuracy: 0.9774 - val_loss: 0.0626 - val_accuracy: 0.9688
# Epoch 86/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.0215 - accuracy: 0.9937 - val_loss: 0.0605 - val_accuracy: 0.9792
# Epoch 87/100
# 100/100 [==============================] - 20s 195ms/step - loss: 0.0695 - accuracy: 0.9786 - val_loss: 0.0623 - val_accuracy: 0.9792
# Epoch 88/100
# 100/100 [==============================] - 19s 187ms/step - loss: 0.0262 - accuracy: 0.9937 - val_loss: 0.0211 - val_accuracy: 0.9896
# Epoch 89/100
# 100/100 [==============================] - 19s 185ms/step - loss: 0.0287 - accuracy: 0.9950 - val_loss: 0.0130 - val_accuracy: 1.0000
# Epoch 90/100
# 100/100 [==============================] - 20s 197ms/step - loss: 0.0259 - accuracy: 0.9899 - val_loss: 0.0123 - val_accuracy: 0.9896
# Epoch 91/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.0272 - accuracy: 0.9899 - val_loss: 0.0279 - val_accuracy: 0.9896
# Epoch 92/100
# 100/100 [==============================] - 20s 198ms/step - loss: 0.0314 - accuracy: 0.9900 - val_loss: 0.0459 - val_accuracy: 0.9896
# Epoch 93/100
# 100/100 [==============================] - 19s 186ms/step - loss: 0.0248 - accuracy: 0.9950 - val_loss: 0.0234 - val_accuracy: 0.9896
# Epoch 94/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.0406 - accuracy: 0.9875 - val_loss: 0.0353 - val_accuracy: 0.9896
# Epoch 95/100
# 100/100 [==============================] - 19s 192ms/step - loss: 0.0170 - accuracy: 0.9962 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 96/100
# 100/100 [==============================] - 19s 189ms/step - loss: 0.0411 - accuracy: 0.9899 - val_loss: 0.0257 - val_accuracy: 1.0000
# Epoch 97/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.0573 - accuracy: 0.9812 - val_loss: 0.0317 - val_accuracy: 0.9792
# Epoch 98/100
# 100/100 [==============================] - 19s 187ms/step - loss: 0.0259 - accuracy: 0.9950 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 99/100
# 100/100 [==============================] - 19s 187ms/step - loss: 0.0163 - accuracy: 0.9962 - val_loss: 0.0408 - val_accuracy: 0.9896
# Epoch 100/100
# 100/100 [==============================] - 20s 193ms/step - loss: 0.0207 - accuracy: 0.9925 - val_loss: 0.0098 - val_accuracy: 1.0000
#
# Modelo y pesos guardados!!!
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-7238949a67dc> in <cell line: 1>()
# ----> 1 cross_validation('DenseNet121', 1)
#
# <ipython-input-14-b8afeaa3d392> in cross_validation(f_arch, f_top_model)
#      25           print(nomenclature)
#      26
# ---> 27           result_test = train_evaluate_save_model(f_arch,epoch, batch, lrate, f_top_model, fold, nomenclature)
#      28
#      29           t_stats.append(result_test)
#
# <ipython-input-13-f8a23374211b> in train_evaluate_save_model(f_arch, f_num_epochs, f_batch, f_lrate, f_top_model, f_nfold, f_nomenclature)
#      31
#      32     # train model
# ---> 33     classifier.train( nb_train_samples = nb_train_samples, nb_validation_samples = nb_validation_samples)
#      34
#      35     # evaluate model
#
# <ipython-input-12-bfa50d41cdff> in train(self, nb_train_samples, nb_validation_samples)
#     115
#     116       # Plot histoy
# --> 117       plot_loss_accurancy(history, self.nomenclature)
#     118
#     119
#
# <ipython-input-7-5a95cb141189> in plot_loss_accurancy(history, write_path)
#      27
#      28   #Guardar gráficos
# ---> 29   fig_accu.savefig(os.path.join(gb_result_dir, write_path + 'accu.png'))
#      30   fig_loss.savefig(os.path.join(gb_result_dir, write_path + 'loss.png'))
#      31
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3341                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3342
# -> 3343             self.canvas.print_figure(fname, **kwargs)
#    3344
#    3345     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2364                 # force the figure dpi to 72), so we need to set it again here.
#    2365                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366                     result = print_method(
#    2367                         filename,
#    2368                         facecolor=facecolor,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in <lambda>(*args, **kwargs)
#    2230                 "bbox_inches_restore"}
#    2231             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234         else:  # Let third-parties do as they see fit.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs)
#     507             *metadata*, including the default 'Software' key.
#     508         """
# --> 509         self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#     510
#     511     def print_to_buffer(self):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     456         """
#     457         FigureCanvasAgg.draw(self)
# --> 458         mpl.image.imsave(
#     459             filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1687         pil_kwargs.setdefault("format", format)
#    1688         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1689         image.save(fname, **pil_kwargs)
#    1690
#    1691
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2426                 fp = builtins.open(filename, "r+b")
#    2427             else:
# -> 2428                 fp = builtins.open(filename, "w+b")
#    2429
#    2430         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/ResultadosEntrenamiento/Otros/PerrosGatos/2_DenseNet121_sm1_bch8_lr0.0001_ep100_ada_Fold0_accu.png'

# %%
print('Fin!!!')
